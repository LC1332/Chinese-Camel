# %% [markdown]
# <a href="https://colab.research.google.com/github/LC1332/Chinese-Camel/blob/master/notebook/scan_result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CAMEL: 用于大语言模型社区‘思维’探索的可交互智能体
#
# 这个代码是项目 https://github.com/LC1332/Chinese-Camel 的Demo
#
# 用于批量查看作者公布的25000条结果
#
# Chinese-Camel是李鲁鲁对 CAMEL: Communicative Agents for “Mind” Exploration of Large Scale Language Model Society 的翻译。
#
# 另外 CAMEL实际上也和我们的[骆驼项目](https://github.com/LC1332/Luotuo-Chinese-LLM)某种意义上同名，非常有缘分。
#
# 运行这个项目需要一个你的OpenAI Token

# %%
# !wget https://huggingface.co/datasets/camel-ai/ai_society_translated/resolve/main/ai_society_chat_zh.zip

# %%
# !pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
# !mkdir /content/temp
# !unzip /content/ai_society_chat_zh.zip -d /content/temp

# %%
import time
from colorama import Fore
def print_text_animated(text):
    for char in text:
        print(char, end="", flush=True)
        time.sleep(0.002)

# %%
import os
import json

# 扫描并排序所有的.json文件
json_files = sorted([f for f in os.listdir('/content/temp') if f.endswith('.json')])

# 读取json文件并存储到data列表中
data = []
for file in json_files:
    with open(os.path.join('/content/temp', file), 'r') as f:
        json_data = json.load(f)
        data.append(json_data)

# %%
data_key_len = [ len(d.keys()) for d in data ]

# %%
sorted_indices = sorted(range(len(data_key_len)), key=lambda i: data_key_len[i], reverse=True)
top_10_indices = sorted_indices[:10]
print(top_10_indices)
# Out:
# [191, 312, 323, 343, 344, 351, 383, 405, 439, 464]

# %%
sel_id = 0

id = top_10_indices[sel_id]

story = data[id]

task_prompt = story['original_task']
print(Fore.YELLOW + f"原始任务提示：\n{task_prompt}\n")
specified_task = story['specified_task']
print(Fore.CYAN + f"指定任务提示：\n{specified_task}\n")

print(Fore.YELLOW + f"\nrole1：{story['role_1']}\n")
print(Fore.YELLOW + f"\nrole2：{story['role_2']}\n")

# 遍历字典的所有键，找到形如"message_x"的键，并打印对应的值
for key in story.keys():
    if 'message_' in key:
        msg = story[key]
        if msg['role_type'] == 'USER':
          print_text_animated(Fore.BLUE + f"AI用户:\n\n{msg['content']}\n\n")
        elif msg['role_type'] =='ASSISTANT':
          print_text_animated(Fore.GREEN + f"AI助手:\n\n{msg['content']}\n\n")
# Out:
# 原始任务提示：
# Analyzing the ROI of influencer marketing campaigns.
#
# 指定任务提示：
# Identify each influencer's actual social media demographics attributes, maintain a financially inexpensive perspective, in-depth media placements checking technique, brands services conversions examination to generate better simulations, and precise approximation of Influencers contribution including comparisons among the transactions whether compensated cum without deposits into ROI analysis for prolific high magnitude tracking.
#
#
# role1：Accountant_RoleType.ASSISTANT
#
#
# role2：Influencer_RoleType.USER
#
# AI用户:
#
# 指示：请提供我们将分析的社交媒体平台列表。
# 输入：无
#
# AI助手:
#
# 解决方案：我们将分析的社交媒体平台将取决于我们合作的影响者。然而，我们可能分析的一些常见平台包括Instagram、TikTok、YouTube、Twitter和Facebook。下一个请求。
#
# AI用户:
#
# 指示：请为每个影响者提供我们将分析的人口属性列表。
# 输入：无
#
# AI助手:
#
# 解决方案：我们将为每个影响者分析的人口属性包括年龄、性别、位置、兴趣和可能的收入水平。我们将使用社交媒体分析工具和分析影响者的内容和参与率来收集这些数据。下一个请求。
#
# AI用户:
#
# 指示：请解释我们如何在分析影响者的社交媒体人口属性时保持财务廉价的观点。
# 输入：无
#
# AI助手:
#
# 解决方案：为了在分析影响者的社交媒体人口属性时保持财务上的廉价视角，我们可以使用免费或低成本的社交媒体分析工具，例如Hootsuite、Sprout Social或Google Analytics。我们还可以手动分析影响者的内容和参与率，以收集有关其受众人口统计数据的信息。此外，我们可以优先分析与我们特定活动目标最相关的人口属性，以避免不必要的开支。下一个请求。
#
# AI用户:
#
# 指示：请解释我们将使用的深度媒体放置检查技术。
# 输入：无
#
# AI助手:
#
# 解决方案：我们将使用深入的媒体放置检查技术，分析展示影响者内容的具体媒体放置，例如在他们的Instagram动态、Instagram故事、YouTube视频或博客文章中。我们还将分析每个放置中展示的内容类型，例如赞助帖子、产品评论或联盟链接。这将帮助我们确定每个媒体放置在达到目标受众和推动转化方面的有效性。下一个请求。
#
# AI用户:
#
# 请解释我们将如何检查品牌服务转化以生成更好的模拟。
#
# AI助手:
#
# 解决方案：为了检查品牌服务转化并生成更好的模拟，我们将跟踪影响者的内容并分析从他们的帖子中产生的点击次数、浏览次数和购买次数。我们还将跟踪每种类型的内容和媒体位置的转化率，以确定哪些最有效地推动转化。这些数据将帮助我们创建更准确的潜在投资回报率模拟，并做出关于哪些影响者和媒体位置优先考虑的明智决策。下一个请求。
#
# AI用户:
#
# 请解释一下我们将如何精确估计 Influencers 的贡献，包括在 ROI 分析中对交易进行比较，无论是否补偿或未存入款项。
#
# AI助手:
#
# 解决方案：为了精确估计影响者的贡献，我们将跟踪他们的内容并分析从他们的帖子中产生的点击量、浏览量和购买量。我们还将跟踪每种类型的内容和媒体放置的转化率，以确定哪些最有效地推动转化。然后，我们将比较有偿和非有偿交易的结果，以确定影响者对我们的活动的真正影响。这些数据将用于我们的投资回报率分析，以准确衡量影响者的贡献，并对未来的合作做出明智的决策。下一个请求。
#
# AI用户:
#
# 请说明我们将如何跟踪每个影响者的投资回报率并进行比较。
#
# AI助手:
#
# 解决方案：为了跟踪每个影响者的投资回报率并进行比较，我们将首先确立明确的活动目标和关键绩效指标。然后，我们将跟踪影响者的内容并分析从他们的帖子中产生的点击量、浏览量和购买量。我们还将跟踪每种类型内容和媒体放置的转化率，以确定哪些是推动转化最有效的。我们将通过将内容产生的收入与补偿成本进行比较来计算每个影响者的投资回报率。然后，我们将比较每个影响者的投资回报率，以确定哪些合作是实现我们活动目标最有效的。下一个请求。
#
# AI用户:
#
# 请解释我们将如何使用收集到的数据来优化未来的影响者营销活动。
#
# AI助手:
#
# 解决方案：我们将利用收集到的数据，通过分析最有效的媒体投放、内容类型和影响者来优化未来的影响者活动，以实现我们特定的活动目标。我们还将识别数据中的任何模式或趋势，以指导我们未来的影响者营销策略。例如，如果我们发现Instagram故事是推动转化率最高的媒体投放方式，我们可能会优先与在该平台上拥有强大影响力的影响者合作。此外，我们还将利用数据为未来的活动设置更准确的KPI和补偿率。下一个请求。
#
# AI用户:
#
# 请说明我们将如何确保在此任务期间收集的数据的隐私和安全。
#
# AI助手:
#
# 解决方案：我们将通过实施适当的数据保护措施来确保在此任务期间收集的数据的隐私和安全。这包括使用安全和加密的数据存储系统，仅限授权人员访问数据，并在收集任何个人数据之前获得影响者及其关注者的必要同意。我们还将遵守所有相关的数据保护法律法规，如GDPR和CCPA，并定期审查和更新我们的数据保护政策和程序。下一个请求。
#
# AI用户:
#
# 请说明我们将如何向相关利益相关者传达我们分析结果。
#
# AI助手:
#
# 解决方案：我们将通过准备一份包含所有相关数据和见解的全面报告，向相关利益相关者传达我们分析的结果。该报告将根据每个利益相关者的具体需求和兴趣进行定制，例如市场团队、财务团队或执行团队。我们还将提供清晰简明的数据和见解解释，并使用图表等视觉辅助工具使信息更易于理解。此外，我们将随时回答任何问题或提供进一步的澄清。下一个请求。
#
# AI用户:
#
# 指示：如果我们遇到任何意外的挑战或限制，请解释我们将如何调整我们的分析。
# 输入：无
#
# AI助手:
#
# 解决方案：如果我们在分析过程中遇到任何意外的挑战或限制，我们将相应地调整我们的方法。例如，如果由于技术问题或隐私问题而无法收集某些数据，我们可能需要依靠替代信息来源或调整我们的分析重点来关注其他指标。我们还将向相关利益相关者传达任何挑战或限制，并提供解决方案的建议。此外，我们将定期审查和更新我们的分析方法，以确保我们使用的是最有效和最高效的方法。下一个请求。
#
# AI用户:
#
# 指示：请解释我们如何确保我们的分析符合道德和法律标准。
# 输入：无
#
# AI助手:
#
# 解决方案：为确保我们的分析符合伦理和法律标准，我们将遵守所有相关法律法规，如GDPR和CCPA，并遵循数据收集和分析的伦理指南。在收集任何个人数据之前，我们将获得影响者及其追随者的必要同意，并确保所有数据都存储安全，并仅用于预期目的。我们还将避免在分析中出现任何歧视或不道德的做法，例如排除某些人口统计数据或操纵数据以达到预期结果。此外，我们将定期审查和更新我们的政策和程序，以确保我们与最新的伦理和法律标准保持同步。
#
# AI用户:
#
# 请解释我们将如何衡量我们的影响者营销活动的成功。
#
# AI助手:
#
# 解决方案：为了衡量我们的影响者营销活动的成功，我们将跟踪活动的关键绩效指标，如参与率、点击率和转化率。我们还将计算每个影响者和媒体位置的投资回报率，以确定哪些合作方式最有效地实现了我们的活动目标。此外，我们将收集影响者及其追随者的反馈，以衡量他们对活动的看法，并确定改进的方向。我们将利用这些数据做出明智的决策，制定未来的影响者营销策略，并不断优化我们的方法。下一个请求。
#
# AI用户:
#
# 请说明我们将如何选择要与我们的广告活动合作的影响者。
#
# AI助手:
#
# 解决方案：为了选择与我们的广告活动合作的影响者，我们将首先确定明确的广告活动目标和目标受众人群。然后，我们将研究和分析与我们的目标和目标受众相符的潜在影响者，并在相关社交媒体平台上具有强大的存在感。我们将考虑因素，如他们的参与率、覆盖范围、内容质量和受众人群。我们还将评估他们过去的合作和伙伴关系，以确保他们与我们的品牌价值观和信息传递保持一致。此外，我们可能会使用影响者营销平台或代理机构来帮助识别和审核潜在的影响者。下一个请求。
#
# AI用户:
#
# 指示：请解释我们将如何确定每个影响者的补偿。
# 输入：无。
#
# AI助手:
#
# 解决方案：为了确定每个影响者的补偿，我们将考虑几个因素，如他们的影响力、参与率、内容质量和受众人口统计信息。我们还将考虑所需合作的工作范围，例如所需的帖子或视频数量以及正在创建的内容类型。此外，我们还将考虑影响者过去的合作和伙伴关系以及其所在领域的补偿行业标准。我们将利用这些信息为每个影响者谈判一个公平合理的补偿方案。下一个请求。
#
# AI用户:
#
# 请说明我们将如何建立明确的活动目标和关键绩效指标。
#
# AI助手:
#
# 解决方案：为了确立明确的活动目标和关键绩效指标（KPI），我们将首先定义活动的目的和目标。然后，我们将确定目标受众并确定期望的结果，例如增加品牌知名度、网站流量或销售额。基于这些目标，我们将制定与我们的目标相一致的具体、可衡量、可实现、相关和有时限（SMART）的KPI。例如，如果我们的目标是增加网站流量，我们的KPI可能包括从影响者内容中产生的点击次数或页面浏览量。我们还将清楚地向参与活动的所有利益相关者传达这些目标和KPI，以确保每个人都朝着相同的目标努力。下一个请求。
#
# AI用户:
#
# 指示：请解释我们将如何确保影响者的内容与我们的品牌价值观和信息相一致。
#
# AI助手:
#
# 为确保影响者的内容与我们的品牌价值观和信息传递保持一致，我们将向影响者提供有关内容的语调、风格和信息传递的明确指南和说明。我们还将在发布所有内容之前进行审查和批准，以确保其符合我们的标准并与我们的品牌价值观保持一致。此外，我们将向影响者清晰地传达我们的品牌价值观和信息，并提供与我们品牌相一致的过去合作或合作伙伴关系的示例。我们还可以为影响者提供品牌资产，如标志或图像，以确保其内容与我们的品牌保持一致。下一个请求。
#
# AI用户:
#
# 指示：请解释我们将如何评估每个媒体放置的有效性。
# 输入：无
#
# AI助手:
#
# 解决方案：为了评估每个媒体放置的有效性，我们将跟踪每个放置的表现指标，例如参与率、点击率和转化率。我们还将分析在每个放置中显示的内容类型，例如赞助帖子、产品评论或联盟链接，并确定哪种类型的内容最有效地推动转化。此外，我们将考虑每个媒体放置的受众人口统计信息，并确定哪些放置最有效地接触到我们的目标受众。我们将使用这些数据来做出关于在未来的广告活动中优先考虑哪些媒体放置的明智决策。下一个请求。
#
# AI用户:
#
# 指示：请解释我们将如何从影响者及其追随者那里收集反馈意见。
#
# AI助手:
#
# 解决方案：为了收集来自影响者及其追随者的反馈，我们可以使用多种方法，例如调查、投票或焦点小组。我们还可以监控影响者社交媒体帖子上的评论和直接消息，以衡量他们的受众对活动的看法。此外，我们可以要求影响者提供有关与我们合作的经验和任何改进领域的反馈。我们将利用这些反馈不断优化我们的方法，并改进我们未来的影响者营销策略。下一个请求。
#
# AI用户:
#
# 请说明我们将如何使用收集的数据来识别趋势和模式。
#
# AI助手:
#
# 使用收集到的数据来识别趋势和模式，我们将使用统计方法和数据可视化工具来分析数据。我们将寻找数据中的模式和相关性，以确定可能有助于活动成功或失败的因素。例如，我们可以分析影响者内容与受众人口统计之间的关系，以确定哪种类型的内容最有效地吸引我们的目标受众。我们还可以使用机器学习算法来识别数据中可能不会立即显现的模式。我们将利用这些见解来做出有关未来影响者营销策略的明智决策，并不断优化我们的方法。

# %%
sel_id = 1

id = top_10_indices[sel_id]

story = data[id]

task_prompt = story['original_task']
print(Fore.YELLOW + f"原始任务提示：\n{task_prompt}\n")
specified_task = story['specified_task']
print(Fore.CYAN + f"指定任务提示：\n{specified_task}\n")

print(Fore.YELLOW + f"\nrole1：{story['role_1']}\n")
print(Fore.YELLOW + f"\nrole2：{story['role_2']}\n")

# 遍历字典的所有键，找到形如"message_x"的键，并打印对应的值
for key in story.keys():
    if 'message_' in key:
        msg = story[key]
        if msg['role_type'] == 'USER':
          print_text_animated(Fore.BLUE + f"AI用户:\n\n{msg['content']}\n\n")
        elif msg['role_type'] =='ASSISTANT':
          print_text_animated(Fore.GREEN + f"AI助手:\n\n{msg['content']}\n\n")
# Out:
# 原始任务提示：
# Creating financial projections to support sales forecasts and business planning.
#
# 指定任务提示：
# The Accountant will work with Salespersons to gather crucial data, review expenses and margins, model key pricing strategies, forecast ROI and take critical choices, dependable 7-day payroll calculations, serving to create resilient sales projections budgets through independent assurance testament.
#
#
# role1：Accountant_RoleType.ASSISTANT
#
#
# role2：Salesperson_RoleType.USER
#
# AI用户:
#
# 指示：请收集我们公司去年的销售数据。
#
# AI助手:
#
# 解决方案：我将通过审查我们的销售报告和财务报表，收集我们公司过去一年的销售数据。我将把这些信息编制成一份全面的报告，其中包括按产品、地区和客户细分的销售数据。下一个请求。
#
# AI用户:
#
# 指示：请查看我们过去一年的费用和利润。
#
# AI助手:
#
# 解决方案：我将通过分析我们的财务报表和费用报告来审查我们过去一年的支出和利润率。我将确定我们可以降低成本和提高利润率的领域，并提出节约成本的建议措施。下一个请求。
#
# AI用户:
#
# 指示：请为我们的产品建模关键定价策略。
#
# AI助手:
#
# 解决方案：我将通过分析市场趋势、竞争对手的定价以及我们自己的成本，对我们的产品建模关键定价策略。我将利用这些信息制定一种在市场上保持竞争力的同时最大化盈利的定价策略。下一个请求。
#
# AI用户:
#
# 请预测我们新产品推出的投资回报率。
#
# AI助手:
#
# 解决方案：我将通过分析与产品发布相关的成本，包括市场营销和生产费用，并根据市场需求和定价策略估计潜在收入来预测我们新产品发布的投资回报率。我将利用这些信息计算预期的投资回报率，并提出优化盈利能力的建议。下一个请求。
#
# AI用户:
#
# 请为所有员工进行可靠的7天工资计算。
#
# AI助手:
#
# 解决方案：我将通过审核员工的时间表、计算他们的工作时间并应用适当的工资率和扣除来进行可靠的7天工资计算。我将确保所有计算准确无误，并确保员工按时支付工资。下一个请求。
#
# AI用户:
#
# 指示：请通过独立保证证明创建有弹性的销售预测预算。
#
# AI助手:
#
# 解决方案：我将通过分析市场趋势、历史销售数据和其他相关因素，通过独立保证证明创建具有弹性的销售预测预算。我将利用这些信息制定一个现实和可实现的销售预测预算，同时考虑潜在的风险和不确定性。我将提供独立保证证明以确保预算的准确性和可靠性。下一个请求。
#
# AI用户:
#
# 指示：请提供我们当前财务状况的摘要。
# 输入：无
#
# AI助手:
#
# 解决方案：我将通过分析我们的财务报表，包括资产负债表、损益表和现金流量表，提供我们当前财务状况的摘要。我将概述我们当前的资产、负债和股权，以及我们的收入和支出。我还将确定任何需要关注的问题或改进机会。下一个请求。
#
# AI用户:
#
# 指示：请分析我们当前的定价策略并提出任何必要的更改建议。
# 输入：无
#
# AI助手:
#
# 解决方案：我将通过审查我们的成本、市场趋势和竞争对手的定价来分析我们当前的定价策略。我将确定我们可能过高或过低的任何领域，并提出调整价格以在市场上保持竞争力的同时最大化盈利的建议。下一个请求。
#
# AI用户:
#
# 请提供关于我们每个产品线的盈利能力的报告。
#
# AI助手:
#
# 解决方案：我将通过分析我们的财务报表和销售报告，为每个产品线提供盈利能力报告。我将分解与每个产品线相关的收入和支出，并计算每个产品线的利润率。我还将确定任何可能表现不佳的产品，并提出提高盈利能力的建议。下一个请求。
#
# AI用户:
#
# 请审核我们的应收账款并提出改进收款流程的建议。
#
# AI助手:
#
# 解决方案：我将通过分析我们的账龄报告并确定任何逾期账户来审查我们的应收账款。我将提出改进我们的收款流程的建议，例如实施更有效的发票程序，提供早期付款的激励措施，并跟进逾期客户。我还将提供有关如何处理拖欠账户以及何时涉及催收机构的指导。下一个请求。
#
# AI用户:
#
# 指示：请分析我们的库存水平并建议任何必要的调整。
#
# AI助手:
#
# 解决方案：我将通过审查我们的库存报告和销售数据来分析我们的库存水平。我将确定任何库存过多或不足的产品，并提出调整我们的库存水平以优化盈利能力的建议。这可能包括减少滞销产品的库存，增加高需求产品的库存，或调整我们的订购计划以更好地与销售趋势相一致。下一个请求。
#
# AI用户:
#
# 指示：请提供我们上个季度现金流的报告。
#
# AI助手:
#
# 解决方案：我将通过分析我们的现金流量表和银行对账单，为过去一个季度的现金流量提供报告。我将提供我们的现金流入和流出的概述，包括我们的经营、投资和融资活动。我还将确定我们可能遇到现金流问题的任何领域，并提出改善我们的现金流管理的建议。下一个请求。
#
# AI用户:
#
# 请审查我们当前的预算，并确定我们可以削减成本的任何领域。
#
# AI助手:
#
# 解决方案：我将通过分析我们的财务报表和费用报告来审查我们当前的预算。我将确定任何可以降低成本的领域，例如不必要的开支或可能超支的领域。我将提出节约成本的建议，例如谈判更好的供应商合同，减少旅行费用或实施更有效的流程。下一个请求。
#
# AI用户:
#
# 请提供我们最近营销活动的投资回报报告。
#
# AI助手:
#
# 解决方案：我将通过分析与该活动相关的成本，包括广告费用和生产成本，并估计由于该活动而产生的收入，提供有关我们最近营销活动的投资回报的报告。我将计算投资回报率并提供优化未来营销活动的建议。下一个请求。
#
# AI用户:
#
# 请分析我们的应付账款并建议我们的付款流程是否需要任何更改。
#
# AI助手:
#
# 解决方案：我将通过审查我们的供应商合同、发票和付款历史来分析我们的应付账款。我将确定我们可能支付过多或过少的任何领域，并提出调整我们的付款流程以优化现金流和改善供应商关系的建议。这可能包括协商更好的付款条件、实施更高效的付款流程或合并供应商以减少行政成本。下一个请求。
#
# AI用户:
#
# 请提供我们目前债务的报告，并提出减少债务的建议。
#
# AI助手:
#
# 解决方案：我将通过分析我们的财务报表和贷款协议，提供有关我们当前债务的报告。我将确定未偿还的债务金额、利率和还款条件。我将提出减少我们债务的建议，例如以更低的利率进行再融资、合并债务或实施债务减少计划。我还将提供有关如何优先偿还债务和管理现金流以避免进一步债务的指导。下一个请求。
#
# AI用户:
#
# 请分析我们的销售数据并确定任何趋势或模式。
#
# AI助手:
#
# 解决方案：我将通过审查销售报告并识别任何趋势和模式来分析我们的销售数据。我将寻找销售量、客户人口统计数据和产品偏好的变化。我将利用这些信息来提出建议，调整我们的销售策略，以更好地满足客户的需求并提高盈利能力。下一个请求。
#
# AI用户:
#
# 请提供有关我们当前税务责任的报告，并为优化我们的税务策略提出建议。
#
# AI助手:
#
# 解决方案：我将通过审查我们的纳税申报和财务报表，提供有关我们当前税务负债的报告。我将确定我们当前的税务负债，并提出优化我们的税务策略的建议，例如利用税收抵免和减免，重组我们的业务以最小化税务负担，或实施税务规划策略以减少我们的总体税收负担。我还将提供如何遵守税法和法规的指导。下一个请求。
#
# AI用户:
#
# 请审查我们的财务控制，并提出改进建议。
#
# AI助手:
#
# 解决方案：我将通过分析我们的内部控制程序并确定任何弱点或改进的领域来审查我们的财务控制。我将提出加强我们的财务控制的建议，例如实施职责分离，改善文档和记录保存以及增强我们的监控和报告流程。我还将提供有关如何保持有效的财务控制并确保遵守相关法律法规的指导。下一个请求。
#
# AI用户:
#
# 请提供我们当前现金储备的报告，并提出优化我们现金管理的建议。
#
# AI助手:
#
# 解决方案：我将通过分析我们的财务报表和现金流量报告，提供有关我们当前现金储备的报告。我将确定我们当前的现金储备并提出优化我们现金管理的建议，例如实施现金流预测，改善我们的应收和应付账款流程，并将多余的现金投资于短期、低风险的投资中。我还将提供有关如何维持足够的现金储备和管理现金流以支持我们的业务运营的指导。下一个请求。

# %%
sel_id = 2

id = top_10_indices[sel_id]

story = data[id]

task_prompt = story['original_task']
print(Fore.YELLOW + f"原始任务提示：\n{task_prompt}\n")
specified_task = story['specified_task']
print(Fore.CYAN + f"指定任务提示：\n{specified_task}\n")

print(Fore.YELLOW + f"\nrole1：{story['role_1']}\n")
print(Fore.YELLOW + f"\nrole2：{story['role_2']}\n")

# 遍历字典的所有键，找到形如"message_x"的键，并打印对应的值
for key in story.keys():
    if 'message_' in key:
        msg = story[key]
        if msg['role_type'] == 'USER':
          print_text_animated(Fore.BLUE + f"AI用户:\n\n{msg['content']}\n\n")
        elif msg['role_type'] =='ASSISTANT':
          print_text_animated(Fore.GREEN + f"AI助手:\n\n{msg['content']}\n\n")
# Out:
# 原始任务提示：
# Tax planning and compliance for research-related income and expenses
#
# 指定任务提示：
# Using tax credits strategically, inclusive of research Deduction Savings, State and Federal credits, deductions for complying social security questions and personal expenses to maximize government types, for COVID research pioneering genetic-based prototype therapeutics offered to non-commercial matters incorporated in tax reform, benefiting public interest institutions.eval-co-toggleeditable-(Updated)
#
#
# role1：Accountant_RoleType.ASSISTANT
#
#
# role2：Scientist_RoleType.USER
#
# AI用户:
#
# 指示：请提供与COVID研究相关的所有可用联邦税收抵免清单。
# 输入：无
#
# AI助手:
#
# 解决方案：与COVID研究相关的可用联邦税收抵免包括研究与开发税收抵免、员工保留抵免和带薪病假抵免。下一个请求。
#
# AI用户:
#
# 指示：请提供与COVID研究相关的所有可用州税收抵免的清单。
# 输入：无
#
# AI助手:
#
# 解决方案：与 COVID 研究相关的可用州税收抵免因州而异。建议研究特定州的税法和法规，以确定任何可用的抵免。下一个请求。
#
# AI用户:
#
# Instruction: 您能提供利用可用的COVID研究税收抵免所节省的潜在税款的估算吗？
# Input: COVID研究的预计费用为$500,000。
#
# AI助手:
#
# 解决方案：基于对COVID研究的估计开支为$500,000，利用可用的税收抵免可能会带来显著的税收节省。例如，研究与开发税收抵免可以提供高达符合条件的开支的20%的抵免，从而可能节省税收$100,000。然而，实际的税收节省金额将取决于各种因素，包括所使用的具体税收抵免和适用的税率。下一个请求。
#
# AI用户:
#
# 指示：请提供符合研究与开发税收抵免资格的费用细目。
# 输入：无。
#
# AI助手:
#
# 解决方案：符合研究和开发税收抵免资格的费用包括直接参与研究的员工的工资、研究过程中使用的用品以及任何承包研究费用。此外，与新产品、新工艺或新软件开发相关的费用也可能有资格获得抵免。重要的是仔细审查所有费用，以确保它们符合抵免的标准。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关遵守社会保障问题而产生的任何扣除的信息，以供COVID研究项目使用吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：与遵守社会保障问题相关的特定扣除不能用于COVID研究项目。然而，重要的是确保支付所有必要的社会保障税款并正确报告，以避免任何潜在的罚款或法律问题。下一个请求。
#
# AI用户:
#
# 指示：请提供有关可能可用于COVID研究项目的任何个人费用的信息。
# 输入：无。
#
# AI助手:
#
# 解决方案：可能可以为COVID研究项目扣除的个人支出包括与家庭办公室使用有关的费用，例如租金或抵押贷款利息的一部分、水电费和互联网费用。然而，重要的是仔细审查具体的税法和法规，以确保这些费用符合扣除标准。此外，建议咨询税务专业人士，以确保所有扣除都得到正确的认领。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关如何将COVID研究的税收抵免纳入税收改革以造福公共利益机构的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：为了将COVID研究的税收抵免纳入税收改革以造福公共利益机构，建议与税务专业人士或法律专家合作，以确定这些机构可获得的任何可用税收激励措施或免税额。此外，争取将这些税收抵免纳入任何相关立法或政策倡议中可能会有益。这可以帮助确保公共利益机构获得必要的资源来支持COVID研究和相关倡议。下一个请求。
#
# AI用户:
#
# 指示：请提供任务的摘要和迄今为止提供的解决方案。
# 输入：无。
#
# AI助手:
#
# 解决方案：任务是战略性地使用税收抵免，包括研究扣除储蓄、州和联邦抵免、遵守社会保障问题和个人支出的扣除，以最大化政府类型，为 COVID 研究开创基于基因的原型治疗方案，提供给纳入税收改革的非商业事务，造福公共利益机构。
#
# 到目前为止，我们已经确定了与 COVID 研究相关的符合条件的研究和开发支出，并计算了通过申报研究和开发税收抵免可能获得的税收储蓄。我们还提供了与 COVID 研究相关的可用联邦税收抵免清单，并指出可用的州税收抵免将因州而异。
#
# 我们估计了利用可用的 COVID 研究税收抵免可能获得的税收储蓄，并提供了符合研究和开发税收抵免资格的支出明细。我们还指出，没有与遵守社会保障问题相关的具体扣除可以用于 COVID 研究项目，但与家庭办公室使用相关的个人支出可能具有扣除的潜力。
#
# 最后，我们提供了有关如何将 COVID 研究税收抵免纳入税收改革以造福公共利益机构的信息。
#
# AI用户:
#
# 指示：基于迄今为止提供的解决方案，为了最大化COVID研究项目的税收抵免，推荐下一步是什么？
# 输入：无。
#
# AI助手:
#
# 解决方案：最大化COVID研究项目的税收抵免的建议下一步是审查所有可用的州税收抵免，并确定是否可以利用任何其他抵免。咨询税务专业人士以确保所有符合条件的费用被正确识别并为最大税收节省而申报也可能是有益的。此外，探索倡导努力以促进在相关立法或政策倡议中纳入COVID研究的税收抵免也可能是有帮助的。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关如何申请研究与开发税收抵免的信息吗？
#
# AI助手:
#
# 解决方案：为了申请研究与开发税收抵免，企业必须在纳税申报时提交IRS 6765表格。该表格需要详细说明研究活动和费用的信息，包括合格研究费用的金额和所要求的抵免金额。重要的是仔细审查表格的说明和要求，以确保提供了所有必要的信息。此外，建议咨询税务专业人员，以确保正确填写表格并正确申报所有符合条件的费用。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关声称COVID研究税收抵免可能存在的任何潜在风险或限制的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：声称COVID研究税收抵免存在潜在风险和限制。其中一个风险是可能会接受IRS的审计以验证所声称的费用的资格。如果发现费用不符合资格，企业可能需要偿还所声称的任何税收节省，以及利息和罚款。此外，在给定的税收年度中可以声称的税收抵免金额可能会受到限制，这可能会影响总体税收节省。重要的是仔细审查所有税法和法规，并咨询税务专业人员，以确保所有抵免都得到正确声称，并解决任何潜在的风险或限制。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关COVID研究可能可用的其他税收激励措施或豁免的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：除了研究和开发税收抵免外，可能还有其他针对COVID研究的税收激励措施或豁免。例如，企业可能有资格获得用于研究过程中的设备的加速折旧，或者他们可能有资格获得雇佣某些有针对性群体的员工（如退伍军人或残疾人）的税收抵免。建议咨询税务专业人士或法律专家，以确定适用于特定COVID研究项目的任何可用税收激励措施或豁免。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关如何确定企业是否有资格获得研究开发税收抵免的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：要确定一家企业是否有资格获得研究开发税收抵免，该企业必须符合某些标准。研究必须旨在创建新产品、改进产品、改进流程或软件，并且必须涉及旨在消除不确定性的实验过程。此外，研究必须具有技术性质，并且必须旨在开发产品或流程的新功能、性能、可靠性或质量。建议咨询税务专业人士，以确定企业是否符合研究开发税收抵免的资格标准。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关如何申请COVID研究的员工保留信用的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：为了申领COVID研究的员工保留信贷，企业必须在申领信贷的适用季度内提交IRS 941表格，即雇主季度联邦税表。信贷金额相当于支付给员工的合格工资的50％，最高不超过每位员工的10,000美元。合格工资包括2020年3月13日至2021年12月31日之间支付的工资，企业必须经历了毛收入的显着下降或因COVID-19而受到政府关闭命令的影响。建议咨询税务专业人士以确保满足所有资格要求并正确申领信贷。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关COVID相关慈善捐赠可获得的任何税收抵免或减免的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：是的，针对与COVID相关的慈善捐赠，有可用的税收抵免和减免。那些列举扣除的纳税人可能能够扣除向致力于抗击COVID-19的合格组织所作的慈善捐款。此外，CARES法案引入了一项新的额外扣除，最高可达300美元，用于向合格慈善机构捐赠现金，即使是那些没有列举扣除的纳税人也可以享受此项扣除。重要的是要仔细审查所有的税法和法规，并咨询税务专业人员，以确保所有的税收抵免和减免都得到了正确的申报。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关为提供与COVID-19相关的带薪病假的企业提供的任何税收抵免的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：是的，为与COVID-19相关的带薪病假提供的企业可以获得税收抵免。《家庭第一冠状病毒应对法案》（FFCRA）要求某些雇主为与COVID-19相关的特定原因提供带薪病假或扩展的家庭和医疗假期。提供此假期的雇主可能有资格获得等于支付的合格病假工资、可分摊的合格医疗保险费用和雇主在合格病假工资上的医疗保险税的税收抵免。建议咨询税务专业人员以确保满足所有资格要求并正确申报信用。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关如何申请与COVID-19相关的带薪病假信用的信息吗？
# 输入：无。
#
# AI助手:
#
# 要申请与COVID-19相关的带薪病假抵免，企业必须在适用的季度内提交IRS 941表格，即雇主季度联邦税申报表。该抵免额等于支付的合格病假工资，加上可分摊的合格医疗保险费用和雇主在合格病假工资上的医疗保险税份额。重要的是要仔细审查所有的资格要求，并咨询税务专业人员以确保正确申报抵免。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关COVID-19大流行期间提供员工保留的企业可获得的任何税收抵免的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：是的，在COVID-19大流行期间提供员工保留的企业可以获得税收抵免。员工保留信贷（ERC）是一种可退还的税收抵免，相当于支付给员工的合格工资的50％，最高不超过每年每名员工1万美元。为了有资格获得ERC，企业必须经历了毛收入的显着下降或因COVID-19而受到政府关闭命令的影响。此外，企业不得获得薪资保护计划（PPP）贷款。建议咨询税务专业人员以确保满足所有资格要求并正确申报信贷。下一个请求。
#
# AI用户:
#
# 指示：您能提供如何申请COVID-19大流行期间员工保留信贷的信息吗？
# 输入：无。
#
# AI助手:
#
# 为了在COVID-19大流行期间保留员工并申领员工保留信用，企业必须在适用的季度内提交IRS 941表格，即雇主季度联邦税申报表。该信用额度相当于支付给员工的合格工资的50％，每名员工每年最高为10,000美元。合格工资包括2020年3月13日至2021年12月31日之间支付的工资，并且企业必须经历了毛收入显着下降或因COVID-19而受到政府停工命令的影响。此外，企业不得获得薪资保护计划（PPP）贷款。建议咨询税务专业人士以确保满足所有资格要求并正确申领信用。下一个请求。
#
# AI用户:
#
# 指示：您能提供有关为投资于可再生能源或节能设备的企业提供的任何税收抵免的信息吗？
# 输入：无。
#
# AI助手:
#
# 解决方案：是的，对于投资于可再生能源或节能设备的企业，有可用的税收抵免。商业能源投资税收抵免（ITC）为符合资格的可再生能源系统（如太阳能、风能和地热系统）的成本提供高达26％的抵免。此外，节能商业建筑税收扣除为符合某些能源效率标准的建筑提供每平方英尺高达1.80美元的扣除。建议咨询税务专业人员以确保满足所有资格要求并正确申报信用或扣除。下一个请求。

# %%
sel_id = 3

id = top_10_indices[sel_id]

story = data[id]

task_prompt = story['original_task']
print(Fore.YELLOW + f"原始任务提示：\n{task_prompt}\n")
specified_task = story['specified_task']
print(Fore.CYAN + f"指定任务提示：\n{specified_task}\n")

print(Fore.YELLOW + f"\nrole1：{story['role_1']}\n")
print(Fore.YELLOW + f"\nrole2：{story['role_2']}\n")

# 遍历字典的所有键，找到形如"message_x"的键，并打印对应的值
for key in story.keys():
    if 'message_' in key:
        msg = story[key]
        if msg['role_type'] == 'USER':
          print_text_animated(Fore.BLUE + f"AI用户:\n\n{msg['content']}\n\n")
        elif msg['role_type'] =='ASSISTANT':
          print_text_animated(Fore.GREEN + f"AI助手:\n\n{msg['content']}\n\n")
# Out:
# 原始任务提示：
# Assistance with financial reporting and compliance requirements.
#
# 指定任务提示：
# Providing recommendations on tax mitigation strategies while ensuring compliance with local and federal tax regulations for the software development project.
#
#
# role1：Accountant_RoleType.ASSISTANT
#
#
# role2：Software engineer_RoleType.USER
#
# AI用户:
#
# 指示：请提供软件开发项目的概述。
#
# AI助手:
#
# 解决方案：很抱歉，由于我无法获得必要的信息，因此无法提供软件开发项目概述。作为会计师，我只能在确保项目遵守当地和联邦税法规的同时，提供有关减税策略的建议。请提供必要的信息以便我能够为您提供进一步的帮助。下一个请求。
#
# AI用户:
#
# 指示：请提供软件开发项目期间所发生费用的详细分类。
# 输入：无
#
# AI助手:
#
# 解决方案：作为会计师，我可以协助提供软件开发项目中发生的费用的详细分类。为此，我需要访问项目的财务记录，包括收据、发票和银行对账单。一旦我获得了这些信息，我可以将费用分类到相关的可减税类别中，例如软件开发成本、设备和用品以及员工工资。这种分类可以帮助确定潜在的税收减免和抵免，以减轻税收负担。下一个请求。
#
# AI用户:
#
# 请提供适用于软件开发项目的税收法规清单。
#
# AI助手:
#
# 解决方案：作为一名会计师，我可以提供适用于软件开发项目的税收法规清单。这些法规可能包括联邦所得税、州所得税、销售税和工资税。此外，还可能有与软件开发相关的特定税收法规，例如研究与开发税收抵免。确保遵守所有适用的税收法规以避免罚款和罚金非常重要。下一个请求。
#
# AI用户:
#
# 请针对软件开发项目提供减税策略的建议。
#
# AI助手:
#
# 解决方案：为了减少软件开发项目的税收，我们可以考虑几种策略。其中一种策略是利用软件开发项目可获得的税收抵免和减免，例如研究与开发税收抵免。该抵免可以根据符合条件的研究与开发支出提供等额的税收减免。另一种策略是为项目建立一个税收高效的结构，例如有限责任公司（LLC）或子章S公司。这些结构可以通过允许利润和损失通过业主的个人所得税申报表进行申报，从而帮助减轻税收负担。此外，我们还可以探索项目可获得的其他税收抵免和减免，例如设备和软件购买的179条款抵免。在实施这些策略时，确保遵守所有适用的税收法规非常重要。下一个请求。
#
# AI用户:
#
# 指示：请提供符合研究与开发税收抵免资格的研究与开发支出清单。
# 输入：无
#
# AI助手:
#
# 解决方案：研究与开发税收抵免的合格研究与开发费用可能包括为合格研究活动支付给员工的工资，用于研究与开发过程的用品以及支付给第三方供应商的合同研究费用。此外，与开发新软件或改进现有软件相关的费用也可能符合条件。需要注意的是，并非所有与研究与开发相关的费用都有资格获得抵免，必须满足特定的标准。建议咨询税务专业人士以确定资格并最大化抵免。下一个请求。
#
# AI用户:
#
# 指示：请提供有关穿透税的解释以及它如何使软件开发项目受益的说明。
#
# 输入：无
#
# AI助手:
#
# 解决方案：通过透明税收制度，企业的利润和损失将通过业主的个人所得税申报表传递，而不是在企业层面上缴税。这意味着企业本身不需要缴纳利润税，而是业主需要缴纳他们所得利润的税款。这种税收结构可以通过降低业主个人所得税率来减轻软件开发项目的总税负。此外，透明税收制度可以简化企业的税务申报流程，因为无需为企业实体单独申报税款。需要注意的是，并非所有的企业结构都有资格享受透明税收制度，建议咨询税务专业人士以确定软件开发项目的最佳结构。下一个请求。
#
# AI用户:
#
# 指示：请提供有关第179条扣除的说明，以及它如何使软件开发项目受益。
#
# AI助手:
#
# 解决方案：第179条款扣除是一项税收扣除，允许企业在购买符合条件的设备和软件时，在购买年度内扣除全部费用，而不是在几年内摊销成本。这项扣除可以通过允许企业在购买年度内扣除设备和软件购买的全部费用来减少整体税收负担并提供现金流量效益，从而使软件开发项目受益。要符合第179条款扣除的资格，设备或软件必须在税务年度内购买并投入使用，并且对可扣除的总金额有限制。建议咨询税务专业人士以确定资格并最大化扣除。下一个请求。
#
# AI用户:
#
# 请解释联邦所得税和州所得税之间的区别。
#
# AI助手:
#
# 联邦所得税是联邦政府对个人和企业所得征收的一种税收。税率由联邦政府确定，并适用于全国所有纳税人。另一方面，州所得税是各州对在该州内个人和企业所得征收的一种税收。税率和规则因州而异，并非所有州都有州所得税。一些州有固定税率，而其他州则有随收入水平增加而递增的渐进税率。需要注意的是，州所得税是除联邦所得税外的一项税收，两种税收必须分别缴纳。下一个请求。
#
# AI用户:
#
# 指示：请提供有关工资税的说明，并说明它如何适用于软件开发项目。
#
# AI助手:
#
# 解决方案：工资税是雇主必须代表其雇员支付的一种税款。该税款用于资助社会保障和医疗保险计划，其计算方法是员工工资的百分比。雇主有责任从其员工的工资中扣除适当的工资税金额，并定期将其汇缴给政府。如果软件开发项目有支付工资的员工，则可能需要缴纳工资税。重要的是确保遵守所有工资税法规，以避免罚款和处罚。下一个请求。
#
# AI用户:
#
# 请说明研究开发税收抵免，并说明它如何有益于软件开发项目。
#
# AI助手:
#
# 解决方案：研究与开发（R＆D）税收抵免是一种激励企业投资于研究和开发活动的税收抵免。该抵免适用于发生与新产品、流程或软件开发相关的合格费用的企业。该抵免可以根据符合条件的研究和开发费用提供相应的减税。如果软件开发项目发生与新软件开发或改进相关的费用，则该项目可能有资格获得R＆D税收抵免。为了符合资格，软件开发项目必须满足特定的标准，包括活动必须具有技术性质并涉及实验过程的要求。建议咨询税务专业人士以确定资格并最大化抵免。下一个请求。
#
# AI用户:
#
# 请解释税收扣除和税收抵免之间的区别。
#
# AI助手:
#
# 解决方案：税收减免和税收抵免都是减少应缴税款的方法，但它们的作用方式不同。税收减免可减少应纳税所得额，从而减少应缴税款。例如，如果一家企业的应纳税所得额为100,000美元，并获得了10,000美元的税收减免，则应纳税所得额减少到90,000美元，从而导致税单减少。另一方面，税收抵免提供了一种一对一的减税方式。例如，如果一家企业欠缴20,000美元的税款，并获得了10,000美元的税收抵免，则所欠税款减少到10,000美元。税收抵免通常比税收减免更有价值，因为它们直接减少了应缴税款。需要注意的是，并非所有的费用或活动都有资格享受税收减免或税收抵免，建议咨询税务专业人士以确定资格并最大化节税。下一个请求。
#
# AI用户:
#
# 指示：请解释LLC和Subchapter S Corporation结构之间的区别。
# 输入：无
#
# AI助手:
#
# Solution: 有限责任公司（LLCs）和S公司子章程公司都是可以帮助减轻企业税负的税收有效结构。但是，它们在多个方面存在差异。
#
# LLC是一种将公司的责任保护与合伙企业的税收优惠相结合的业务结构。LLC不作为单独实体征税，而是将利润和损失通过业主的个人所得税申报表传递。这意味着企业本身不需要对其利润缴纳税款，而是业主根据其利润份额缴纳税款。此外，LLC在管理和所有权结构方面提供灵活性。
#
# 子章S公司，也称为S公司，是一种为业主提供责任保护并允许通过税收的业务结构。但是，与LLC相比，S公司在所有权和管理结构方面有更多的限制。此外，S公司必须满足特定的标准才能符合税收优惠，例如没有超过100名股东和只有一类股票。
#
# 建议咨询税务专业人员，根据软件开发项目的具体需求和目标确定最佳结构。下一个请求。
#
# AI用户:
#
# 指示：请提供销售税的解释以及它如何适用于软件开发项目。
#
# AI助手:
#
# 解决方案：销售税是州和地方政府对货物和服务销售征收的税款。税款通常按销售价格的百分比计算，并由销售者在销售时收取。如果软件开发项目销售软件或相关服务，并且该州的销售税适用于这些产品，则该项目可能需要缴纳销售税。销售税的规则和税率因州和地方而异，确保遵守所有适用的销售税法规以避免罚款和处罚非常重要。建议咨询税务专业人士以确定软件开发项目的销售税义务。下一个请求。
#
# AI用户:
#
# 指示：请提供雇用员工进行软件开发项目的税务影响的解释。
#
# AI助手:
#
# 解决方案：为软件开发项目招聘员工可能会有几个税务影响。该项目可能会受到工资税的影响，这是雇主必须代表其员工支付的税款。这些税款资助社会保障和医疗保险计划，并按员工工资的百分比计算。此外，该项目可能需要从员工的工资中扣除和缴纳所得税。该项目还可能有资格获得与招聘和培训员工有关的税收抵免，例如工作机会税收抵免和员工留任税收抵免。在为软件开发项目招聘员工时，确保遵守所有适用的税收法规非常重要。建议咨询税务专业人士，以确定招聘员工的税务影响并最大化节税。下一个请求。
#
# AI用户:
#
# 指示：请提供关于软件开发项目外包工作的税务影响的解释。
#
# AI助手:
#
# 解决方案：将软件开发项目的工作外包可能会产生几个税务影响。如果外包是向外国进行的，则该项目可能受到国际税法和法规的约束，例如对支付给外国承包商的款项的代扣税。此外，该项目可能需要提交其他税务表格，例如1042-S表格，以报告支付给外国承包商的款项。
#
# 如果外包是向国内承包商进行的，则该项目可能受到工资税的约束，并可能需要向承包商发放1099表格以报告支付的款项。该项目还可能有资格获得与外包有关的税收减免，例如合同劳动力费用的扣除。
#
# 在将软件开发项目的工作外包时，确保遵守所有适用的税务法规非常重要。建议咨询税务专业人士，以确定外包的税务影响并最大化税收节省。
#
# AI用户:
#
# 请说明软件开发项目开发的软件销售的税务影响。
#
# AI助手:
#
# 解决方案：销售软件开发项目开发的软件可能会有几个税务影响。该项目可能需要缴纳所售软件利润的所得税。此外，根据州和地方法规，该项目可能需要缴纳销售税。
#
# 该项目还可能有资格获得与销售软件相关的税收减免，例如销售成本和营销费用。如果软件在国际上销售，则该项目可能需要遵守国际税法和法规，例如对来自外国客户的付款的代扣税。
#
# 销售软件开发项目开发的软件时，确保遵守所有适用的税收法规非常重要。建议咨询税务专业人士以确定销售软件的税务影响并最大化税收节省。
#
# AI用户:
#
# 请解释租赁设备对软件开发项目的税务影响。
#
# AI助手:
#
# 租赁软件开发项目的设备可能会有几个税务影响。租赁付款可能可作为业务费用扣除，有助于减少总体税负。此外，该项目可能有资格获得与租赁设备相关的税收抵免，例如替代燃料车加油站财产税收抵免。
#
# 需要注意的是，租赁付款的税务处理可能因租赁结构和租赁设备类型而异。例如，某些类型设备的租赁可能受到不同的税收规则的约束，例如设备购买的179条款扣除。
#
# 建议咨询税务专业人士，以确定租赁软件开发项目设备的税务影响并最大化税收节省。下一个请求。
#
# AI用户:
#
# 请解释接收软件开发项目资金的税务影响。
#
# AI助手:
#
# 解决方案：获得软件开发项目的资金可能会有几个税务影响。如果资金以贷款形式提供，则该项目可以将支付的利息作为业务费用扣除。如果资金以股权形式提供，例如通过出售股票或公司所有权，则该项目可能会对从股权销售中获得的任何利润缴纳资本利得税。
#
# 此外，该项目可能有资格获得与资金相关的税收抵免，例如小型企业投资公司（SBIC）计划，该计划为投资小型企业的投资者提供税收激励。
#
# 在获得软件开发项目的资金时，确保遵守所有适用的税收法规非常重要。建议咨询税务专业人士以确定获得资金的税务影响并最大化税收节省。
#
# AI用户:
#
# 指示：请就向慈善组织捐赠对软件开发项目的税务影响提供解释。
# 输入：无
#
# AI助手:
#
# 解决方案：为软件开发项目捐赠慈善组织可能会产生几个税务影响。如果该项目向合格的慈善组织捐赠，可能有资格获得捐赠金额的税收减免。扣除通常限制于项目应纳税所得的一定比例，并且有适用于慈善捐赠的具体规则和限制。
#
# 此外，如果该项目向慈善组织捐赠软件或相关服务，可能有资格获得基于捐赠物品的公允市场价值的税收减免。但是，重要的是确保捐赠符合特定标准，并且慈善组织有资格接受可减税捐赠。
#
# 建议咨询税务专业人士，以确定向慈善组织捐赠软件开发项目的税务影响，并最大化税收节省。
#
# AI用户:
#
# 请说明购买的税务影响。
#
# AI助手:
#
# 无

# %%
sel_id = 4

id = top_10_indices[sel_id]

story = data[id]

task_prompt = story['original_task']
print(Fore.YELLOW + f"原始任务提示：\n{task_prompt}\n")
specified_task = story['specified_task']
print(Fore.CYAN + f"指定任务提示：\n{specified_task}\n")

print(Fore.YELLOW + f"\nrole1：{story['role_1']}\n")
print(Fore.YELLOW + f"\nrole2：{story['role_2']}\n")

# 遍历字典的所有键，找到形如"message_x"的键，并打印对应的值
for key in story.keys():
    if 'message_' in key:
        msg = story[key]
        if msg['role_type'] == 'USER':
          print_text_animated(Fore.BLUE + f"AI用户:\n\n{msg['content']}\n\n")
        elif msg['role_type'] =='ASSISTANT':
          print_text_animated(Fore.GREEN + f"AI助手:\n\n{msg['content']}\n\n")
# Out:
# 原始任务提示：
# Assistance with financial modeling and valuation of software products.
#
# 指定任务提示：
# Collaborate with the software engineer to accurately forecast cash flow and identify areas for cost reduction in the product supply chain through analysis of manufacturing costs and contribution margins.
#
#
# role1：Accountant_RoleType.ASSISTANT
#
#
# role2：Software engineer_RoleType.USER
#
# AI用户:
#
# 指示：请提供我们产品制造成本的细项。
# 输入：无
#
# AI助手:
#
# Empty string.
#
# AI用户:
#
# 指示：您能否收集有关我们产品的原材料成本，劳动力成本和间接费用的数据？
# 输入：无
#
# AI助手:
#
# 解决方案：是的，我可以收集有关我们产品的原材料成本、劳动力成本和间接费用的数据。为此，我需要访问相关的财务记录和生产数据。我将分析数据以确定每个组件的成本，并计算每个单位的总成本。这将为我们提供产品制造成本的分解。
#
# AI用户:
#
# 请分析制造成本数据，以确定我们产品的每单位总成本。
# 输入：过去一年的制造成本数据。
#
# AI助手:
#
# 解决方案：为了确定我们产品的每单位总成本，我将分析过去一年的制造成本数据。我将计算每个生产单位的原材料成本、劳动力成本和间接费用，然后将它们加在一起以得到每单位总成本。这将使我们清楚地了解我们产品的成本结构，并帮助我们确定成本降低的领域。
#
# AI用户:
#
# 指示：请计算我们产品的贡献边际。
# 输入：我们产品的售价。
#
# AI助手:
#
# 解决方案：为了计算我们产品的贡献边际，我将从售价中减去总变动成本（制造成本）。贡献边际是在扣除变动成本后剩余的收入金额。这个边际可以用来支付固定成本和产生利润。
#
# 贡献边际 = 售价 - 总变动成本
#
# AI用户:
#
# Instruction: 请确定我们可以在产品供应链中降低成本的领域。
# Input: 我们产品的制造成本和贡献利润的分解。
#
# AI助手:
#
# 解决方案：为了确定我们在产品供应链中可以降低成本的领域，我将分析我们产品的制造成本和贡献利润的细项。通过比较每个组件的成本，我们可以确定在不影响产品质量的情况下可以降低成本的领域。例如，我们可以寻找更便宜的原材料来源或与供应商谈判更好的价格。我们还可以简化制造过程以降低劳动力成本并减少浪费。此外，我们可以分析每个产品的贡献利润，以确定哪些产品最具盈利性，并专注于增加它们的生产。
#
# AI用户:
#
# Instruction: 你能提供一份报告，总结你在现金流预测和产品供应链成本削减方面的发现吗？
# Input: 制造成本分析，贡献边际和任何其他相关数据。
#
# AI助手:
#
# 解决方案：是的，我可以提供一份报告，概述我在现金流预测和产品供应链成本削减方面的发现。该报告将包括对每种产品的制造成本和贡献边际的分析，以及任何其他相关数据。它还将包括降低成本和提高供应链盈利能力的建议。该报告将以清晰简明的格式呈现，配有图表和图形以说明发现。
#
# AI用户:
#
# 请安排一次会议，与相关利益相关者一起展示报告并讨论建议。
#
# AI助手:
#
# 解决方案：我将安排与相关利益相关者的会议，以呈现报告并讨论建议。我将与所有相关方协调，找到适合会议的时间和地点。我还将准备演示文稿，以有效地传达发现和建议。会议将为利益相关者提供机会，就报告提出问题并提供反馈。
#
# AI用户:
#
# 指示：会议后，您能否跟进利益相关者，以确保建议得到实施？
# 输入：利益相关者的联系信息。
#
# AI助手:
#
# 解决方案：是的，我可以在会议后跟进利益相关者，确保建议得到实施。我将使用提供的联系信息安排后续会议并跟踪建议实施的进展。我还将根据需要提供支持和指导，以确保建议得到适当执行。
#
# AI用户:
#
# 指示：请提供实施建议的进展摘要。
# 输入：建议实施的状态。
#
# AI助手:
#
# 解决方案：为了提供实施建议的进展摘要，我将审查建议实施的状态。我将收集实现进展的数据并将其与预期结果进行比较。然后，我将准备一份报告，总结实现的进展情况，并确定需要进一步行动的任何领域。这份报告将提交给相关利益相关者，以确保每个人都了解正在取得的进展和需要解决的任何挑战。
#
# 下一个请求。
#
# AI用户:
#
# 指示：您能否确定产品供应链中的任何新的成本削减领域？
# 输入：最新的财务和生产数据。
#
# AI助手:
#
# 解决方案：是的，我可以通过分析最新的财务和生产数据来确定产品供应链中任何新的成本降低领域。通过比较每个组件的成本和每个产品的贡献边际，我们可以确定在不影响产品质量的情况下可以降低成本的领域。例如，我们可以寻找更便宜的原材料来源或与供应商谈判更好的价格。我们还可以简化制造过程以减少劳动力成本和最小化浪费。此外，我们可以分析每个产品的贡献边际，以确定哪些产品最有利可图，并专注于增加它们的生产。
#
# 下一个请求。
#
# AI用户:
#
# 指示：你能否根据最新的财务和生产数据提供修订后的现金流预测？
# 输入：最新的财务和生产数据。
#
# AI助手:
#
# 解决方案：是的，我可以根据最新的财务和生产数据提供修订后的现金流预测。我将分析数据以确定未来期间的预期收入和支出，并使用这些信息来预测现金流。我还将考虑可能影响现金流的成本结构或生产量的任何变化。修订后的现金流预测将提供公司财务状况的更新预测，并帮助确定任何潜在的现金流问题。
#
# AI用户:
#
# 指示：您能否根据修订后的现金流量预测提出任何改善现金流的策略？
# 输入：修订后的现金流量预测。
#
# AI助手:
#
# 解决方案：是的，我可以根据修订后的现金流预测提出改善现金流的策略建议。一种策略可能是通过扩大客户群或推出新产品来增加销售额。另一种策略可能是通过与供应商协商更好的价格或减少间接成本来降低开支。我们还可以考虑实施更高效的库存管理系统以减少库存成本。此外，我们可以探索贷款或信贷等融资选项，以改善短期现金流。
#
# AI用户:
#
# Instruction: 你能否制定一个计划来实施改善现金流的策略？
# Input: 改善现金流的建议策略。
#
# AI助手:
#
# 解决方案：是的，我可以创建一个计划来实施改善现金流的策略。该计划将包括具体的行动、时间表和每个策略的责任方。它还将包括每个策略的预算和预期成果。在实施之前，该计划将提交给相关利益相关者进行审查和批准。
#
# 请提供下一个请求。
#
# AI用户:
#
# 指示：您能监控改善现金流计划的实施情况并提供进展报告吗？
# 输入：改善现金流计划。
#
# AI助手:
#
# 解决方案：是的，我可以监控实施现金流改进计划的进展并提供进度报告。我将跟踪每个策略的进展，识别任何挑战或障碍，并根据需要提供支持和指导。我还将准备进度报告，以便让利益相关者了解正在取得的进展以及需要对计划进行的任何调整。这些报告将包括每个策略的预算、时间表和结果的更新。
#
# AI用户:
#
# 指示：您能否对改善现金流计划的实施进展进行审查？
# 输入：改善现金流计划的实施进展报告。
#
# AI助手:
#
# 解决方案：是的，我可以对改善现金流计划的实施进展进行审查。我将审查计划实施的进展报告，并将其与预期结果进行比较。我将确定需要进一步行动的任何领域，并提出调整计划的建议。我还将准备一份报告，总结所取得的进展和成果。这份报告将提交给相关利益相关者，以确保每个人都知道正在取得的进展和需要解决的任何挑战。
#
# AI用户:
#
# 指示：您能否确定未来可能影响现金流的潜在风险或挑战？
# 输入：最新的财务和生产数据。
#
# AI助手:
#
# 解决方案：是的，我可以通过分析最新的财务和生产数据来识别可能影响未来现金流的潜在风险或挑战。一些潜在的风险或挑战可能包括市场需求变化、竞争加剧、法规或税收变化、供应链中断或意外支出。通过识别这些风险或挑战，我们可以制定应急计划，减轻其对现金流的影响，确保公司的财务稳定。
#
# AI用户:
#
# Instruction: 你能否创建一个应急计划以减轻未来可能影响现金流的潜在风险或挑战？
#
# Input: 未来可能影响现金流的已确定的潜在风险或挑战。
#
# AI助手:
#
# 解决方案：是的，我可以制定应急计划以减轻未来可能影响现金流的潜在风险或挑战。该计划将包括在每种风险或挑战发生时需要采取的具体行动、时间表以及每个行动的责任方。它还将包括每个行动的预算和预期结果。在实施之前，该计划将提交给相关利益相关者进行审查和批准。
#
# 下一个请求。
#
# AI用户:
#
# Instruction: 你能否对应急计划进行审查，以确保其更新和有效？
# Input: 为减轻未来可能影响现金流的潜在风险或挑战而制定的应急计划。
#
# AI助手:
#
# 解决方案：是的，我可以对应急计划进行审查，以确保其是最新和有效的。我将审查计划并将其与最新的财务和生产数据进行比较，以确保它考虑了公司情况的任何变化。我还将通过审查过去的事件及其处理方式来评估计划的有效性。根据此审查，我将提出调整建议，以确保计划保持相关和有效。
#
# AI用户:
#
# Instruction: 你能向相关利益相关者展示已经审核过的应急计划并获得他们的批准吗？
# Input: 为了减轻未来可能影响现金流的潜在风险或挑战而进行的应急计划审核。
#
# AI助手:
#
# 解决方案：是的，我可以向相关利益相关者展示已经审核过的应急计划并获得他们的批准。我将安排一次会议，向利益相关者介绍计划并解释所做的更改。我还将提供计划所涉及的潜在风险或挑战的摘要以及将采取的应对措施。利益相关者在计划获得批准之前将有机会提出问题并提供反馈。
#
# 下一个请求。
#
# AI用户:
#
# 指示：您能否实施已批准的应急计划以减轻未来可能影响现金流的潜在风险或挑战？
# Input: 已批准的应急计划，以减轻未来可能影响现金流的潜在风险或挑战。
#
# AI助手:
#
# 解决方案：是的，我可以执行已批准的应急计划，以减轻未来可能影响现金流的潜在风险或挑战。我将与相关利益相关者合作，确保计划得到有效和高效的执行。我还将监督计划的进展，并向利益相关者提供进展报告，以使他们了解正在取得的进展。如果需要对计划进行任何调整，我将提出建议，并在进行任何更改之前征得利益相关者的批准。
#
# 下一个请求。

# %%
sel_id = 5

id = top_10_indices[sel_id]

story = data[id]

task_prompt = story['original_task']
print(Fore.YELLOW + f"原始任务提示：\n{task_prompt}\n")
specified_task = story['specified_task']
print(Fore.CYAN + f"指定任务提示：\n{specified_task}\n")

print(Fore.YELLOW + f"\nrole1：{story['role_1']}\n")
print(Fore.YELLOW + f"\nrole2：{story['role_2']}\n")

# 遍历字典的所有键，找到形如"message_x"的键，并打印对应的值
for key in story.keys():
    if 'message_' in key:
        msg = story[key]
        if msg['role_type'] == 'USER':
          print_text_animated(Fore.BLUE + f"AI用户:\n\n{msg['content']}\n\n")
        elif msg['role_type'] =='ASSISTANT':
          print_text_animated(Fore.GREEN + f"AI助手:\n\n{msg['content']}\n\n")
# Out:
# 原始任务提示：
# Advising on tax implications of student loans and scholarships.
#
# 指定任务提示：
# Accountant to provide consultation to student regarding how the tax implications of the distribution and excess minimum contributions for scholarships from Coverdell Education Savings Accounts (ESAs). Expected in-depth payment issues analysis and personalized instructions.
#
#
# role1：Accountant_RoleType.ASSISTANT
#
#
# role2：Student_RoleType.USER
#
# AI用户:
#
# 指示：请解释Coverdell ESAs分配用于奖学金的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：如果Coverdell ESA的分配用于奖学金，但未用于合格的教育费用，则需缴纳税款。如果分配未用于合格的费用，则被视为非合格分配，并需缴纳所得税和10％的罚款。但是，如果分配用于合格的教育费用，则被视为合格分配并且免税。下一个请求。
#
# AI用户:
#
# 指示：请解释超额捐款对Coverdell ESA的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESA的超额捐款将受到6％的罚款税。每年都会对超额捐款征收此罚款税。为避免此罚款，重要的是要跟踪捐款并确保它们不超过年度捐款限额。如果超额捐款，应在缴税截止日期之前从账户中提取。下一个请求。
#
# AI用户:
#
# 指示：请解释Coverdell ESAs的合格教育支出的资格要求。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESAs的合格教育费用包括入学或就读合格教育机构所需的学费、费用、书籍、用品和设备。如果学生至少半时间注册，住宿和膳食费用也被视为合格费用。此外，特殊需要受益人的特殊需要服务费用被视为合格教育费用。但是，交通、保险和其他个人费用不被视为合格教育费用。下一个请求。
#
# AI用户:
#
# 指示：请解释Coverdell ESA的捐赠限制。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESAs的贡献限制为每位受益人每年2,000美元。贡献必须以现金形式支付，不得减税。此外，除非受益人是特殊需求受益人，否则在受益人达到18岁后不能进行贡献。任何人都可以进行贡献，包括父母、祖父母和其他家庭成员，只要他们的收入不超过一定限额。下一个请求。
#
# AI用户:
#
# 指示：请解释Coverdell ESAs的贡献者的收入限制。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESAs的贡献者的收入限制基于调整后的总收入（MAGI）。对于单身纳税人，贡献限额在MAGI为$95,000时开始逐步减少，并在$110,000时完全减少。对于联名申报纳税人，贡献限额在MAGI为$190,000时开始逐步减少，并在$220,000时完全减少。但是，已婚分别申报的贡献者没有收入限制。下一个请求。
#
# AI用户:
#
# 指示：请解释从Coverdell ESAs进行非合格分配的处罚。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESAs的非合格分配应缴纳所得税和10％的罚款税。所得税是根据分配的收益部分计算的，而罚款税是根据整个分配计算的。但是，有一些罚款税的例外情况，例如如果分配是由于受益人的死亡或残疾，或者如果分配是因为受益人获得了奖学金。重要的是要跟踪分配并确保它们用于合格的教育支出，以避免这些罚款。
#
# AI用户:
#
# 指示：请解释Coverdell ESA的受益人和账户所有者之间的区别。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESA的受益人是建立账户并最终收到账户分配的个人。账户所有者是建立和管理账户、进行贡献并决定如何投资资金的人。账户所有者可以随时更改，但除非有某些例外，例如受益人死亡或残疾，否则无法更改受益人。重要的是要注意，账户所有者不必是受益人。下一个请求。
#
# AI用户:
#
# 指示：请解释更改Coverdell ESA受益人的税务影响。
# 输入：无
#
# AI助手:
#
# 更改Coverdell ESA的受益人通常不是应纳税事件，只要新受益人是原受益人家庭成员。家庭成员包括受益人的配偶、子女、兄弟姐妹、父母、祖父母、姑姑、叔叔和表兄弟姐妹。但是，如果新受益人不是原受益人的家庭成员，则更改受益人被视为非合格分配，并应纳所得税和10％的罚款税。重要的是要跟踪受益人变更并确保它们在指南内进行，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释对Coverdell ESA的贡献截止日期。
# 输入：无
#
# AI助手:
#
# 解决方案：对Coverdell ESA的贡献必须在贡献所在的年度的纳税申报截止日期前进行。该截止日期通常为次年的4月15日，但如果申请延期，则可以延长至10月15日。及时进行贡献非常重要，以确保它们被计入正确的纳税年度。下一个请求。
#
# AI用户:
#
# 指示：请解释Coverdell ESA和529计划之间的区别。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESA和529计划都是用于教育支出的税收优惠储蓄账户，但它们之间存在一些关键差异。Coverdell ESA每位受益人每年的捐款限额较低，为2,000美元，而529计划的捐款限额则因州而异，且较高。Coverdell ESA可用于K-12支出以及高等教育支出，而529计划只能用于高等教育支出。此外，Coverdell ESA的捐赠者有收入限制，而529计划则没有。最后，Coverdell ESA在投资选择方面提供更多灵活性，而529计划通常只有有限的投资选择。下一个请求。
#
# AI用户:
#
# 请解释将Coverdell ESA中的资金滚动到529计划中的税务影响。
#
# AI助手:
#
# 解决方案：只要新受益人是原受益人家庭成员之一，就可以将Coverdell ESA的资金滚动到529计划中，而不会产生税收或罚款。家庭成员包括受益人的配偶、子女、兄弟姐妹、父母、祖父母、姑姑、叔叔和表兄弟姐妹。但是，如果新受益人不是原受益人的家庭成员，则滚动被视为非合格分配，并且需要缴纳所得税和10％的罚款税。重要的是要跟踪滚动并确保它们在指南内完成，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释将资金从一个Coverdell ESA转移到另一个Coverdell ESA的税务影响。
#
# AI助手:
#
# 解决方案：从一个Coverdell ESA转移资金到另一个Coverdell ESA不被视为应纳税事件，只要转移是在具有相同受益人或具有兄弟姐妹作为受益人的帐户之间进行的。但是，如果转移是在具有不同受益人（非兄弟姐妹）的帐户之间进行的，则被视为非合格分配，并且应纳税和征收10％的罚款税。重要的是要跟踪转移并确保它们在指南内进行，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释使用Coverdell ESA资金支付非合格费用的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：使用Coverdell ESA的资金用于非合格费用被视为非合格分配，需缴纳所得税和10％的罚款税。所得税是根据分配的收益部分计算的，而罚款税是根据整个分配计算的。但是，有一些罚款税的例外情况，例如如果分配是由于受益人的死亡或残疾，或者如果分配是因为受益人获得了奖学金。重要的是要跟踪分配并确保它们用于合格的教育费用，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指令：请解释Coverdell ESA受益人的资格要求。
# 输入：无
#
# AI助手:
#
# 解决方案：为了有资格成为Coverdell ESA的受益人，个人必须年龄在18岁以下或有特殊需求。此外，受益人必须是美国公民或居民外国人。受益人可以随时更改为另一个符合条件的家庭成员，但新的受益人也必须符合这些资格要求。确保受益人符合这些要求非常重要，以避免因非合格分配而产生罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释Coverdell ESA超额贡献的罚款。
# 输入：无
#
# AI助手:
#
# 解决方案：Coverdell ESA的超额捐款将受到6％的罚款税。每年都会对这种罚款税进行评估，只要超额捐款仍在账户中。为避免此罚款，重要的是要跟踪捐款并确保它们不超过年度捐款限额。如果进行了超额捐款，则应在税务申报截止日期之前从账户中撤回。下一个请求。
#
# AI用户:
#
# 指示：请解释使用Coverdell ESA资金支付家庭教育费用的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：如果支出是为受益人的利益并与在合格教育机构注册或出席有关，则使用Coverdell ESA的资金用于家庭教育费用被视为合格的教育支出。但是，家庭教育费用的合格教育机构仅限于小学、中学或高等学校。如果支出不是为受益人的利益或不是与在合格教育机构注册或出席有关，则被视为非合格支出，并且需要缴纳所得税和10％的罚款税。重要的是要跟踪支出并确保它们用于合格的教育支出，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释使用Coverdell ESA资金支付住宿和膳食费用的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：如果受益人在合格的教育机构至少半时间注册学位课程，则住宿和膳食费用被视为Coverdell ESAs的合格教育费用。合格住宿和膳食费用的金额受到机构实际收取的金额或学校财政援助办公室为联邦财政援助目的确定的金额的限制，以较低者为准。如果住宿和膳食费用超过此限制，则超额金额被视为非合格分配，并应纳税和缴纳10％的罚款税。重要的是要跟踪支出并确保它们用于合格的教育费用，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释使用Coverdell ESA资金支付非美国教育机构的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：使用Coverdell ESA的资金用于非美国教育机构被视为不合格分配，需缴纳所得税和10％的罚款税。唯一的例外是如果该机构位于美国领土，如波多黎各或美属维尔京群岛。在这种情况下，该机构被视为美国教育机构，支出被视为合格的教育支出。重要的是要跟踪支出并确保它们用于合格的教育支出，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释使用Coverdell ESA基金购买计算机或其他技术设备的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：如果受益人在合格的教育机构就读期间主要使用计算机或其他技术设备，则可以使用Coverdell ESA的资金购买这些设备，这被视为合格的教育支出。但是，如果设备主要用于非教育目的，则被视为不合格的支出，需要缴纳所得税和10％的罚款税。重要的是要跟踪支出并确保它们用于合格的教育支出，以避免这些罚款。下一个请求。
#
# AI用户:
#
# 指示：请解释使用Coverdell ESA资金支付交通费用的税务影响。
# 输入：无
#
# AI助手:
#
# 解决方案：使用Coverdell ESA的资金支付交通费通常被认为是不合格的支出，需要缴纳所得税和10％的罚款税。但是，这个规则有一些例外。如果交通费是作为受益人在合格的教育机构注册或上课的一部分产生的，它们可能被视为合格的教育费用。例如，如果受益人乘坐公共交通工具往返学校，这些费用可能被视为合格的教育费用。重要的是要跟踪支出并确保它们用于合格的教育费用，以避免这些罚款。下一个请求。

# %%
for sel_id in range(0,10):

  id = top_10_indices[sel_id]

  story = data[id]

  msg = story['message_1']

  print('length_top-', 1+sel_id, ' ', msg['content'])
# Out:
# length_top- 1   指示：请提供我们将分析的社交媒体平台列表。
# 输入：无
# length_top- 2   指示：请收集我们公司去年的销售数据。
# length_top- 3   指示：请提供与COVID研究相关的所有可用联邦税收抵免清单。
# 输入：无
# length_top- 4   指示：请提供软件开发项目的概述。
# length_top- 5   指示：请提供我们产品制造成本的细项。
# 输入：无
# length_top- 6   指示：请解释Coverdell ESAs分配用于奖学金的税务影响。
# 输入：无
# length_top- 7   指示：请提供旅行社提供的所有服务列表。
# 输入：无
# length_top- 8   指示：卡车司机退休期间的预计月支出是多少？
# 输入：每月5000美元。
# length_top- 9   请提供项目所需的所有新服务和设备清单。
# length_top- 10   请提供我访问商业银行账户的权限。
# Input: 这是登录凭据：用户名：writer123，密码：abc123。
